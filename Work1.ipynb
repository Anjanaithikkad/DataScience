# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0,3])
y = np.array([1,10])

plt.subplot(2, 3, 1)
plt.plot(x,y,'o')
plt.title("Title 1")
plt.xlabel("x label-Blue color")
plt.ylabel("y label-Blue color")

x = np.array([20,10,20,10,20])
y = np.array([10, 20, 10, 20,10])

plt.subplot(2, 3, 2)
plt.plot(x,ls='--')
plt.plot(y,ls='-',marker='*',color='orange',linewidth=2.5)

y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(y,'o-',ms=10,mec='black',mfc='yellow')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title("Title 2")
plt.xticks(np.arange(0, 4.1, 1))       
plt.yticks(np.arange(10, 45, 5)) 
plt.grid()

x = np.array([5,20,80,17,23,47,22,30,14])
y = np.array([99,86,87,88,111,86,103,87,94])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60])
sizes = np.array([20,30,50,70,60,90,70,10,60])
plt.subplot(2, 3, 5)
plt.scatter(x, y,c=colors, s=sizes,alpha=0.5)

x = np.array(["A", "B", "C"])
y = np.array([3, 8, 1])

plt.subplot(2, 3, 6)
plt.bar(x, y,color="red", width = 0.1)

plt.tight_layout(pad=3.0)

plt.title("Graph")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([30, 20, 20, 25])
mylabels = ["25", "35", "20", "20"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, colors=mycolors, explode = myexplode, shadow = True)
plt.legend()
plt.show()
